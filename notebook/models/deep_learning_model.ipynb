# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("../../data/encoded_dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100244 entries, 0 to 100243
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   admission_type_id         100244 non-null  int64
#  1   discharge_disposition_id  100244 non-null  int64
#  2   admission_source_id       100244 non-null  int64
#  3   time_in_hospital          100244 non-null  int64
#  4   medical_specialty         100244 non-null  int64
#  5   num_lab_procedures        100244 non-null  int64
#  6   num_procedures            100244 non-null  int64
#  7   num_medications           100244 non-null  int64
#  8   number_outpatient         100244 non-null  int64
#  9   number_emergency          100244 non-null  int64
#  10  number_inpatient          100244 non-null  int64
#  11  diag_1                    100244 non-null  int64
#  12  diag_2                    100244 non-null  int64
#  13  diag_3                    100244 non-null  int64
#  14  number_diagnoses          100244 non-null  int64
#  15  metformin                 100244 non-null  float64
#  16  repaglinide               100244 non-null  float64
#  17  nateglinide               100244 non-null  float64
#  18  chlorpropamide            100244 non-null  float64
#  19  glimepiride               100244 non-null  float64
#  20  acetohexamide             100244 non-null  int64
#  21  glipizide                 100244 non-null  float64
#  22  glyburide                 100244 non-null  float64
#  23  tolbutamide               100244 non-null  int64
#  24  pioglitazone              100244 non-null  float64
#  25  rosiglitazone             100244 non-null  float64
#  26  acarbose                  100244 non-null  float64
#  27  miglitol                  100244 non-null  float64
#  28  troglitazone              100244 non-null  int64
#  29  tolazamide                100244 non-null  float64
#  30  insulin                   100244 non-null  float64
#  31  glyburide-metformin       100244 non-null  float64
#  32  glipizide-metformin       100244 non-null  int64
#  33  glimepiride-pioglitazone  100244 non-null  int64
#  34  metformin-rosiglitazone   100244 non-null  int64
#  35  metformin-pioglitazone    100244 non-null  int64
#  36  change                    100244 non-null  bool
#  37  diabetesMed               100244 non-null  bool
#  38  readmitted                100244 non-null  int64
#  39  race_AfricanAmerican      100244 non-null  bool
#  40  race_Asian                100244 non-null  bool
#  41  race_Caucasian            100244 non-null  bool
#  42  race_Hispanic             100244 non-null  bool
#  43  race_Other                100244 non-null  bool
#  44  age_[0-10)                100244 non-null  bool
#  45  age_[10-20)               100244 non-null  bool
#  46  age_[20-30)               100244 non-null  bool
#  47  age_[30-40)               100244 non-null  bool
#  48  age_[40-50)               100244 non-null  bool
#  49  age_[50-60)               100244 non-null  bool
#  50  age_[60-70)               100244 non-null  bool
#  51  age_[70-80)               100244 non-null  bool
#  52  age_[80-90)               100244 non-null  bool
#  53  age_[90-100)              100244 non-null  bool
#  54  gender_Female             100244 non-null  bool
#  55  gender_Male               100244 non-null  bool
#  56  gender_other              100244 non-null  bool
# dtypes: bool(20), float64(14), int64(23)
# memory usage: 30.2 MB

# %%
# Prepare features (X) and target variable (y)
X = df.drop(columns=["readmitted"])
y = df["readmitted"]

# Convert categorical features to numeric if necessary
X = pd.get_dummies(X)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
X
# Out:
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       1                         1                    7
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       2                         1                    2
# ...                   ...                       ...                  ...
# 100239                  1                         3                    7
# 100240                  1                         4                    5
# 100241                  1                         1                    7
# 100242                  2                         3                    7
# 100243                  1                         1                    7
#
#         time_in_hospital  medical_specialty  num_lab_procedures  \
# 0                      3                  0                  59
# 1                      2                  0                  11
# 2                      2                  0                  44
# 3                      1                  0                  51
# 4                      3                  0                  31
# ...                  ...                ...                 ...
# 100239                 3                  0                  51
# 100240                 5                  0                  33
# 100241                 1                  0                  53
# 100242                10                  4                  45
# 100243                 6                  0                  13
#
#         num_procedures  num_medications  number_outpatient  number_emergency  \
# 0                    0               18                  0                 0
# 1                    5               13                  2                 0
# 2                    1               16                  0                 0
# 3                    0                8                  0                 0
# 4                    6               16                  0                 0
# ...                ...              ...                ...               ...
# 100239               0               16                  0                 0
# 100240               3               18                  0                 0
# 100241               0                9                  1                 0
# 100242               2               21                  0                 0
# 100243               3                3                  0                 0
#
#         ...  age_[30-40)  age_[40-50)  age_[50-60)  age_[60-70)  age_[70-80)  \
# 0       ...        False        False        False        False        False
# 1       ...        False        False        False        False        False
# 2       ...         True        False        False        False        False
# 3       ...        False         True        False        False        False
# 4       ...        False        False         True        False        False
# ...     ...          ...          ...          ...          ...          ...
# 100239  ...        False        False        False        False         True
# 100240  ...        False        False        False        False        False
# 100241  ...        False        False        False        False         True
# 100242  ...        False        False        False        False        False
# 100243  ...        False        False        False        False         True
#
#         age_[80-90)  age_[90-100)  gender_Female  gender_Male  gender_other
# 0             False         False           True        False         False
# 1             False         False           True        False         False
# 2             False         False          False         True         False
# 3             False         False          False         True         False
# 4             False         False          False         True         False
# ...             ...           ...            ...          ...           ...
# 100239        False         False          False         True         False
# 100240         True         False           True        False         False
# 100241        False         False          False         True         False
# 100242         True         False           True        False         False
# 100243        False         False          False         True         False
#
# [100244 rows x 56 columns]

# %%
X_scaled
# Out:
# array([[-0.70783402, -0.5168113 ,  0.30503934, ...,  0.92685256,
#         -0.92679677, -0.00547064],
#        [-0.70783402, -0.5168113 ,  0.30503934, ...,  0.92685256,
#         -0.92679677, -0.00547064],
#        [-0.70783402, -0.5168113 ,  0.30503934, ..., -1.07892025,
#          1.0789852 , -0.00547064],
#        ...,
#        [-0.70783402, -0.5168113 ,  0.30503934, ..., -1.07892025,
#          1.0789852 , -0.00547064],
#        [-0.01574806, -0.13809516,  0.30503934, ...,  0.92685256,
#         -0.92679677, -0.00547064],
#        [-0.70783402, -0.5168113 ,  0.30503934, ..., -1.07892025,
#          1.0789852 , -0.00547064]])

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long)

# %%
y_train_tensor
# Out:
# tensor([0, 1, 0,  ..., 0, 1, 0])

# %%
# deep neural network model
class SimpleNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Initialize model
input_dim = X_train.shape[1]
hidden_dim = 64
output_dim = len(y.unique())  # Number of classes
model = SimpleNN(input_dim, hidden_dim, output_dim)

# loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training
epochs = 1000
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 5 == 0:
        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch
# Epoch [765/1000], Loss: 0.6116
# Epoch [770/1000], Loss: 0.6115
# Epoch [775/1000], Loss: 0.6113
# Epoch [780/1000], Loss: 0.6112
# Epoch [785/1000], Loss: 0.6111
# Epoch [790/1000], Loss: 0.6110
# Epoch [795/1000], Loss: 0.6109
# Epoch [800/1000], Loss: 0.6107
# Epoch [805/1000], Loss: 0.6106
# Epoch [810/1000], Loss: 0.6105
# Epoch [815/1000], Loss: 0.6104
# Epoch [820/1000], Loss: 0.6102
# Epoch [825/1000], Loss: 0.6101
# Epoch [830/1000], Loss: 0.6100
# Epoch [835/1000], Loss: 0.6099
# Epoch [840/1000], Loss: 0.6098
# Epoch [845/1000], Loss: 0.6097
# Epoch [850/1000], Loss: 0.6096
# Epoch [855/1000], Loss: 0.6095
# Epoch [860/1000], Loss: 0.6094
# Epoch [865/1000], Loss: 0.6093
# Epoch [870/1000], Loss: 0.6092
# Epoch [875/1000], Loss: 0.6091
# Epoch [880/1000], Loss: 0.6089
# Epoch [885/1000], Loss: 0.6088
# Epoch [890/1000], Loss: 0.6087
# Epoch [895/1000], Loss: 0.6086
# Epoch [900/1000], Loss: 0.6085
# Epoch [905/1000], Loss: 0.6084
# Epoch [910/1000], Loss: 0.6083
# Epoch [915/1000], Loss: 0.6082
# Epoch [920/1000], Loss: 0.6081
# Epoch [925/1000], Loss: 0.6080
# Epoch [930/1000], Loss: 0.6079
# Epoch [935/1000], Loss: 0.6078
# Epoch [940/1000], Loss: 0.6078
# Epoch [945/1000], Loss: 0.6077
# Epoch [950/1000], Loss: 0.6076
# Epoch [955/1000], Loss: 0.6075
# Epoch [960/1000], Loss: 0.6075
# Epoch [965/1000], Loss: 0.6074
# Epoch [970/1000], Loss: 0.6073
# Epoch [975/1000], Loss: 0.6073
# Epoch [980/1000], Loss: 0.6072
# Epoch [985/1000], Loss: 0.6072
# Epoch [990/1000], Loss: 0.6071
# Epoch [995/1000], Loss: 0.6071
# Epoch [1000/1000], Loss: 0.6070

# %%
# evaluate model
model.eval()
with torch.no_grad():
    outputs = model(X_test_tensor)
    _, predicted = torch.max(outputs, 1)

    accuracy = accuracy_score(y_test_tensor, predicted)
    class_report = classification_report(y_test_tensor, predicted, output_dict=True)

    print(f"Accuracy: {accuracy:.4f}")
    print("Classification Report:")
    for label, metrics in class_report.items():
        print(f"{label}:")
        print(metrics)
# Out:
# Accuracy: 0.6171
# Classification Report:
# 0:
# {'precision': 0.6274066633182656, 'recall': 0.6990952336535771, 'f1-score': 0.6613138042087616, 'support': 10721.0}
# 1:
# {'precision': 0.6018758484511909, 'recall': 0.5228344768439108, 'f1-score': 0.559577763754231, 'support': 9328.0}
# accuracy:
# 0.6170881340715247
# macro avg:
# {'precision': 0.6146412558847283, 'recall': 0.6109648552487439, 'f1-score': 0.6104457839814963, 'support': 20049.0}
# weighted avg:
# {'precision': 0.6155281935152793, 'recall': 0.6170881340715247, 'f1-score': 0.6139800825588109, 'support': 20049.0}
