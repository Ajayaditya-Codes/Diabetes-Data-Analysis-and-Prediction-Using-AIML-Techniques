# %%
import pandas as pd

# %%
#import dataframe
df = pd.read_csv("../../data/dataset.csv")
# Out:
# /tmp/ipykernel_4744/142752171.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      99493 non-null   object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    3197 non-null    object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                61510 non-null   object
#  9   medical_specialty         51817 non-null   object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
#  13  number_outpatient         101766 non-null  int64
#  14  number_emergency          101766 non-null  int64
#  15  number_inpatient          101766 non-null  int64
#  16  diag_1                    101745 non-null  object
#  17  diag_2                    101408 non-null  object
#  18  diag_3                    100343 non-null  object
#  19  number_diagnoses          101766 non-null  int64
#  20  max_glu_serum             5346 non-null    object
#  21  A1Cresult                 17018 non-null   object
#  22  metformin                 101766 non-null  object
#  23  repaglinide               101766 non-null  object
#  24  nateglinide               101766 non-null  object
#  25  chlorpropamide            101766 non-null  object
#  26  glimepiride               101766 non-null  object
#  27  acetohexamide             101766 non-null  object
#  28  glipizide                 101766 non-null  object
#  29  glyburide                 101766 non-null  object
#  30  tolbutamide               101766 non-null  object
#  31  pioglitazone              101766 non-null  object
#  32  rosiglitazone             101766 non-null  object
#  33  acarbose                  101766 non-null  object
#  34  miglitol                  101766 non-null  object
#  35  troglitazone              101766 non-null  object
#  36  tolazamide                101766 non-null  object
#  37  examide                   101766 non-null  object
#  38  citoglipton               101766 non-null  object
#  39  insulin                   101766 non-null  object
#  40  glyburide-metformin       101766 non-null  object
#  41  glipizide-metformin       101766 non-null  object
#  42  glimepiride-pioglitazone  101766 non-null  object
#  43  metformin-rosiglitazone   101766 non-null  object
#  44  metformin-pioglitazone    101766 non-null  object
#  45  change                    101766 non-null  object
#  46  diabetesMed               101766 non-null  object
#  47  readmitted                101766 non-null  object
# dtypes: int64(11), object(37)
# memory usage: 37.3+ MB

# %%
df.apply(pd.Series.unique)
# Out:
# 0               Caucasian
# 1               Caucasian
# 2         AfricanAmerican
# 3               Caucasian
# 4               Caucasian
#                ...
# 101761    AfricanAmerican
# 101762    AfricanAmerican
# 101763          Caucasian
# 101764          Caucasian
# 101765          Caucasian
# Name: race, Length: 101766, dtype: object
# 0         Female
# 1         Female
# 2         Female
# 3           Male
# 4           Male
#            ...
# 101761      Male
# 101762    Female
# 101763      Male
# 101764    Female
# 101765      Male
# Name: gender, Length: 101766, dtype: object
# 0          [0-10)
# 1         [10-20)
# 2         [20-30)
# 3         [30-40)
# 4         [40-50)
#            ...
# 101761    [70-80)
# 101762    [80-90)
# 101763    [70-80)
# 101764    [80-90)
# 101765    [70-80)
# Name: age, Length: 101766, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 101761    NaN
# 101762    NaN
# 101763    NaN
# 101764    NaN
# 101765    NaN
# Name: weight, Length: 101766, dtype: object
# 0         6
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 101761    1
# 101762    1
# 101763    1
# 101764    2
# 101765    1
# Name: admission_type_id, Length: 101766, dtype: int64
# 0         25
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 101761     3
# 101762     4
# 101763     1
# 101764     3
# 101765     1
# Name: discharge_disposition_id, Length: 101766, dtype: int64
# 0         1
# 1         7
# 2         7
# 3         7
# 4         7
#          ..
# 101761    7
# 101762    5
# 101763    7
# 101764    7
# 101765    7
# Name: admission_source_id, Length: 101766, dtype: int64
# 0          1
# 1          3
# 2          2
# 3          2
# 4          1
#           ..
# 101761     3
# 101762     5
# 101763     1
# 101764    10
# 101765     6
# Name: time_in_hospital, Length: 101766, dtype: int64
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 101761     MC
# 101762     MC
# 101763     MC
# 101764     MC
# 101765    NaN
# Name: payer_code, Length: 101766, dtype: object
# 0         Pediatrics-Endocrinology
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#                     ...
# 101761                         NaN
# 101762                         NaN
# 101763                         NaN
# 101764             Surgery-General
# 101765                         NaN
# Name: medical_specialty, Length: 101766, dtype: object
# 0         41
# 1         59
# 2         11
# 3         44
# 4         51
#           ..
# 101761    51
# 101762    33
# 101763    53
# 101764    45
# 101765    13
# Name: num_lab_procedures, Length: 101766, dtype: int64
# 0         0
# 1         0
# 2         5
# 3         1
# 4         0
#          ..
# 101761    0
# 101762    3
# 101763    0
# 101764    2
# 101765    3
# Name: num_procedures, Length: 101766, dtype: int64
# 0          1
# 1         18
# 2         13
# 3         16
# 4          8
#           ..
# 101761    16
# 101762    18
# 101763     9
# 101764    21
# 101765     3
# Name: num_medications, Length: 101766, dtype: int64
# 0         0
# 1         0
# 2         2
# 3         0
# 4         0
#          ..
# 101761    0
# 101762    0
# 101763    1
# 101764    0
# 101765    0
# Name: number_outpatient, Length: 101766, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 101761    0
# 101762    0
# 101763    0
# 101764    0
# 101765    0
# Name: number_emergency, Length: 101766, dtype: int64
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 101761    0
# 101762    1
# 101763    0
# 101764    1
# 101765    0
# Name: number_inpatient, Length: 101766, dtype: int64
# 0         250.83
# 1            276
# 2            648
# 3              8
# 4            197
#            ...
# 101761    250.13
# 101762       560
# 101763        38
# 101764       996
# 101765       530
# Name: diag_1, Length: 101766, dtype: object
# 0            NaN
# 1         250.01
# 2            250
# 3         250.43
# 4            157
#            ...
# 101761       291
# 101762       276
# 101763       590
# 101764       285
# 101765       530
# Name: diag_2, Length: 101766, dtype: object
# 0         NaN
# 1         255
# 2         V27
# 3         403
# 4         250
#          ...
# 101761    458
# 101762    787
# 101763    296
# 101764    998
# 101765    787
# Name: diag_3, Length: 101766, dtype: object
# 0          1
# 1          9
# 2          6
# 3          7
# 4          5
#           ..
# 101761     9
# 101762     9
# 101763    13
# 101764     9
# 101765     9
# Name: number_diagnoses, Length: 101766, dtype: int64
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 101761    NaN
# 101762    NaN
# 101763    NaN
# 101764    NaN
# 101765    NaN
# Name: max_glu_serum, Length: 101766, dtype: object
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 101761     >8
# 101762    NaN
# 101763    NaN
# 101764    NaN
# 101765    NaN
# Name: A1Cresult, Length: 101766, dtype: object
# 0             No
# 1             No
# 2             No
# 3             No
# 4             No
#            ...
# 101761    Steady
# 101762        No
# 101763    Steady
# 101764        No
# 101765        No
# Name: metformin, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: repaglinide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: nateglinide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: chlorpropamide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: glimepiride, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: acetohexamide, Length: 101766, dtype: object
# 0             No
# 1             No
# 2         Steady
# 3             No
# 4         Steady
#            ...
# 101761        No
# 101762        No
# 101763        No
# 101764    Steady
# 101765        No
# Name: glipizide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: glyburide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: tolbutamide, Length: 101766, dtype: object
# 0             No
# 1             No
# 2             No
# 3             No
# 4             No
#            ...
# 101761        No
# 101762        No
# 101763        No
# 101764    Steady
# 101765        No
# Name: pioglitazone, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: rosiglitazone, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: acarbose, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: miglitol, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: troglitazone, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: tolazamide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: examide, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: citoglipton, Length: 101766, dtype: object
# 0             No
# 1             Up
# 2             No
# 3             Up
# 4         Steady
#            ...
# 101761      Down
# 101762    Steady
# 101763      Down
# 101764        Up
# 101765        No
# Name: insulin, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: glyburide-metformin, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: glipizide-metformin, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: glimepiride-pioglitazone, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: metformin-rosiglitazone, Length: 101766, dtype: object
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 101761    No
# 101762    No
# 101763    No
# 101764    No
# 101765    No
# Name: metformin-pioglitazone, Length: 101766, dtype: object
# 0         No
# 1         Ch
# 2         No
# 3         Ch
# 4         Ch
#           ..
# 101761    Ch
# 101762    No
# 101763    Ch
# 101764    Ch
# 101765    No
# Name: change, Length: 101766, dtype: object
# 0          No
# 1         Yes
# 2         Yes
# 3         Yes
# 4         Yes
#          ...
# 101761    Yes
# 101762    Yes
# 101763    Yes
# 101764    Yes
# 101765     No
# Name: diabetesMed, Length: 101766, dtype: object
# 0          NO
# 1         >30
# 2          NO
# 3          NO
# 4          NO
#          ...
# 101761    >30
# 101762     NO
# 101763     NO
# 101764     NO
# 101765     NO
# Name: readmitted, Length: 101766, dtype: object
# race                        None
# gender                      None
# age                         None
# weight                      None
# admission_type_id           None
# discharge_disposition_id    None
# admission_source_id         None
# time_in_hospital            None
# payer_code                  None
# medical_specialty           None
# num_lab_procedures          None
# num_procedures              None
# num_medications             None
# number_outpatient           None
# number_emergency            None
# number_inpatient            None
# diag_1                      None
# diag_2                      None
# diag_3                      None
# number_diagnoses            None
# max_glu_serum               None
# A1Cresult                   None
# metformin                   None
# repaglinide                 None
# nateglinide                 None
# chlorpropamide              None
# glimepiride                 None
# acetohexamide               None
# glipizide                   None
# glyburide                   None
# tolbutamide                 None
# pioglitazone                None
# rosiglitazone               None
# acarbose                    None
# miglitol                    None
# troglitazone                None
# tolazamide                  None
# examide                     None
# citoglipton                 None
# insulin                     None
# glyburide-metformin         None
# glipizide-metformin         None
# glimepiride-pioglitazone    None
# metformin-rosiglitazone     None
# metformin-pioglitazone      None
# change                      None
# diabetesMed                 None
# readmitted                  None
# dtype: object

# %%
#large number of na. handling creates inaccuracies
df.drop(columns=["weight", "max_glu_serum", "A1Cresult", "payer_code"], inplace=True)

# %%
df["race"] = df["race"].fillna("Other")
df["medical_specialty"] = df["medical_specialty"].fillna("Unknown")
df.dropna(inplace=True)

# %%
#convert to suitable datatype - categories

df.convert_dtypes()

for col in df.select_dtypes(include=["object"]).columns:
    df[col] = df[col].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100244 entries, 1 to 101765
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      100244 non-null  category
#  1   gender                    100244 non-null  category
#  2   age                       100244 non-null  category
#  3   admission_type_id         100244 non-null  int64
#  4   discharge_disposition_id  100244 non-null  int64
#  5   admission_source_id       100244 non-null  int64
#  6   time_in_hospital          100244 non-null  int64
#  7   medical_specialty         100244 non-null  category
#  8   num_lab_procedures        100244 non-null  int64
#  9   num_procedures            100244 non-null  int64
#  10  num_medications           100244 non-null  int64
#  11  number_outpatient         100244 non-null  int64
#  12  number_emergency          100244 non-null  int64
#  13  number_inpatient          100244 non-null  int64
#  14  diag_1                    100244 non-null  category
#  15  diag_2                    100244 non-null  category
#  16  diag_3                    100244 non-null  category
#  17  number_diagnoses          100244 non-null  int64
#  18  metformin                 100244 non-null  category
#  19  repaglinide               100244 non-null  category
#  20  nateglinide               100244 non-null  category
#  21  chlorpropamide            100244 non-null  category
#  22  glimepiride               100244 non-null  category
#  23  acetohexamide             100244 non-null  category
#  24  glipizide                 100244 non-null  category
#  25  glyburide                 100244 non-null  category
#  26  tolbutamide               100244 non-null  category
#  27  pioglitazone              100244 non-null  category
#  28  rosiglitazone             100244 non-null  category
#  29  acarbose                  100244 non-null  category
#  30  miglitol                  100244 non-null  category
#  31  troglitazone              100244 non-null  category
#  32  tolazamide                100244 non-null  category
#  33  examide                   100244 non-null  category
#  34  citoglipton               100244 non-null  category
#  35  insulin                   100244 non-null  category
#  36  glyburide-metformin       100244 non-null  category
#  37  glipizide-metformin       100244 non-null  category
#  38  glimepiride-pioglitazone  100244 non-null  category
#  39  metformin-rosiglitazone   100244 non-null  category
#  40  metformin-pioglitazone    100244 non-null  category
#  41  change                    100244 non-null  category
#  42  diabetesMed               100244 non-null  category
#  43  readmitted                100244 non-null  category
# dtypes: category(33), int64(11)
# memory usage: 12.7 MB

# %%
#export as csv
df.to_csv('../../data/cleaned_dataset.csv', index = False)
